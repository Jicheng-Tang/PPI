# %%
import processors_mint as pm

# %% [markdown]
# #1、依据验证实验类型（高置信、低通量）筛选

# %%
pm.experiment_method('mint_allspecies.mitab25.txt')

# %% [markdown]
# #2、提取Uniprot_id

# %%
pm.Uniprot_id()
# Out:
# c:\Users\ABCD\Desktop\test\mint\processors_mint.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["A_id"] = filtered_df["protein1_uniprot"].str.replace("uniprotkb:", "")
# c:\Users\ABCD\Desktop\test\mint\processors_mint.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["B_id"] = filtered_df["protein2_uniprot"].str.replace("uniprotkb:", "")

# %% [markdown]
# #3、去重

# %%
pm.rm_repetition()

# %% [markdown]
# #4、提取ppi序列

# %%
pm.ppi_seq('uniprot_sprot.fasta','uniprot_id.csv')

# %% [markdown]
# #5、长度（1024）过滤

# %%
pm.filter_len()
